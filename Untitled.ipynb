# %% [markdown]
# # 1. Convolutional Neural Networks (CNNs)
#
# Affine neural networks usually don't scale very well to full images. Although, in the case of CIFAR dataset, images are size of 32x32x3 (32 wide, 32 high, 3 color channels), so a single fully connected layer would have 32*32*3 = 3072 weights which can handle easily but this structure is not manageable for large images with many layers, e.g. 200x200x3, would lead neurons that have 200*200*3 = 120,000 weights. Thus, the number of parameters grows very fast which can be led to overfitting problem. Also, another advantage of convolutional neural network is that it takes advantage of image classification because it can consider edges and information about the location of a pixel because the neurons in a layer will only be connected to a small region of the layer before it, instead of all of the neurons in a fully-connected manner. CNN capacity can be controlled by varying their depth and breadth, and they also make strong and mostly correct assumptions about the nature of images (namely, stationarity of statistics and locality of pixel dependencies). In addition, convolutional neural network has a big advantage over affine layers in terms of regularization.

# %% [markdown]
# # 2. CNNs in more depth
#
# To understand bettter what is happening in a CNN, we can have a look on the picture below[^1].

# %%
from IPython.display import Image
Image('images/CNN.png')

# %% [markdown]
# To keep every thing simple, we suppose our inputs (images) are so simple (9x9 pix) and they have only one channel. In additionan, our convolutioanl layer has only one 3 by 3 filter.
# A convolutional layer is consisted from 3 parts:
#
# 1. convolution operator
# 2. Activation function
# 3. Pooling layer
#
# ## 2.1. Covolution operator
#
# In the first step, the filter is moved over the entire picture. In fact, a filter is a matrix of weights (in our example 3 by 3 matrix). Each cell of filter is multiplied by its corresponding cell in the filter like the picture above. The step size by wich the filter is moved from top left corner of the picture (coordination (0,0)) to the bottom right corner of the picture is called "stride". It is set by you. Finding the ture value for it is kind of experimental. Machine learning engineers usually try differnt values and observe the results then pick the value with the best result. However, it is very common to set it to one. It means the filter is moved one pixel to right until it reaches the end of the frame then it is moved one pixel down and again starts from left side to scan the whole picture. I used the term "scan" becuase in fact a filter is responsible to find a specific patter in the entire picture. For example, consider the picture above. The filter scans the picture to fnd the left to right patter in the picture.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.metrics import confusion_matrix
import time
from datetime import timedelta
import math

# %%
tf.__version__
# Out:
# '0.12.1'
